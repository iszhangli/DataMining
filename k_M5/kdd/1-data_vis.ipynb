# %%
# 可视化常规导入
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import cycle

pd.set_option('max_columns', 50)
plt.style.use('bmh')
color_pal = plt.rcParams['axes.prop_cycle'].by_key()['color']
color_cycle = cycle(plt.rcParams['axes.prop_cycle'].by_key()['color'])

# %%
INPUT_DIR = 'C:\\ZhangLI\\Codes\\DataSet\\kdd-cup'
demo = pd.read_csv(f'{INPUT_DIR}/sdwpf134_initial_kddcup.csv')

# %%
# 这里引申出一个问题来
demo
# Out:
#        TurbID  Day Tmstamp  Wspd   Wdir   Etmp   Itmp   Ndir   Pab1   Pab2  \
# 0           1    1   00:00  2.81  -2.00  16.61  30.95  148.0   0.03   0.03
# 1           1    1   00:15  2.48  -4.30  16.38  30.83  148.0   0.03   0.03
# 2           1    1   00:30  1.16   9.28  16.62  31.05  135.0   0.03   0.03
# 3           1    1   00:45  0.92  14.38  16.13  31.20  148.0   0.04   0.04
# 4           1    1   01:00  1.38  -4.28  15.12  29.52  148.0  89.68  89.69
# ...       ...  ...     ...   ...    ...    ...    ...    ...    ...    ...
# 90043     134    7   22:45  9.94   1.90  22.75  22.63  181.0  90.40  90.39
# 90044     134    7   23:00  9.94   1.90  22.75  22.63  181.0  90.40  90.39
# 90045     134    7   23:15  9.94   1.90  22.75  22.63  181.0  90.40  90.39
# 90046     134    7   23:30  9.94   1.90  22.75  22.63  181.0  90.40  90.39
# 90047     134    7   23:45  9.94   1.90  22.75  22.63  181.0  90.40  90.39
#
#         Pab3   Prtv    Patv
# 0       0.03 -19.38  111.13
# 1       0.03 -15.69   75.30
# 2       0.03  -2.50    9.54
# 3       0.03  -0.70    0.00
# 4      89.50  -0.30    0.00
# ...      ...    ...     ...
# 90043  90.00  -0.30    0.00
# 90044  90.00  -0.30    0.00
# 90045  90.00  -0.30    0.00
# 90046  90.00  -0.30    0.00
# 90047  90.00  -0.30    0.00
#
# [90048 rows x 13 columns]
