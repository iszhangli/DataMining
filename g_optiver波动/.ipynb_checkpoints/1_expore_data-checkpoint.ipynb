# %%
import pandas as pd
path = 'C:/ZhangLI/Codes/DataSet/optiver-realized-volatility-prediction/'
train = pd.read_csv(path + "train.csv")
book_example = pd.read_parquet(path + 'book_train.parquet/stock_id=0')
trade_example = pd.read_parquet(path + "trade_train.parquet/stock_id=0")

# %%
book_example[book_example.time_id==5]
# trade_example[trade_example.time_id==5]
# Out:
#      time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  \
# 0          5                  0    1.001422    1.002301    1.001370
# 1          5                  1    1.001422    1.002301    1.001370
# 2          5                  5    1.001422    1.002301    1.001370
# 3          5                  6    1.001422    1.002301    1.001370
# 4          5                  7    1.001422    1.002301    1.001370
# ..       ...                ...         ...         ...         ...
# 297        5                585    1.003129    1.003749    1.003025
# 298        5                586    1.003129    1.003749    1.002612
# 299        5                587    1.003129    1.003749    1.003025
# 300        5                588    1.003129    1.003749    1.002612
# 301        5                593    1.003129    1.003749    1.003025
#
#      ask_price2  bid_size1  ask_size1  bid_size2  ask_size2
# 0      1.002353          3        226          2        100
# ...

# %%
import matplotlib.pyplot as plt
book_test = book_example[book_example.time_id==5]
trade_test = trade_example[trade_example["time_id"]==5]
plt.figure(figsize=(20,4))
samples = ["bid_price1","bid_price2","ask_price1","ask_price2"]
for index, col in enumerate(samples):
    plt.plot(book_test["seconds_in_bucket"],book_test[col],label=col)
plt.plot(trade_test["seconds_in_bucket"],trade_test["price"],label="trade_parquet",lw=10)
plt.legend(fontsize=12)

# %%
# book time
book_example.time_id.unique().shape
# trade time
trade_example.time_id.unique().shape
# price spread
# volumn
# volumn imblance
book_example
# Out:
#         time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  \
# 0             5                  0    1.001422    1.002301    1.001370
# 1             5                  1    1.001422    1.002301    1.001370
# 2             5                  5    1.001422    1.002301    1.001370
# 3             5                  6    1.001422    1.002301    1.001370
# 4             5                  7    1.001422    1.002301    1.001370
# ...         ...                ...         ...         ...         ...
# 917548    32767                568    0.998275    0.998754    0.997796
# 917549    32767                569    0.998275    0.998754    0.997892
# 917550    32767                571    0.998275    0.998754    0.997892
# 917551    32767                572    0.998275    0.998754    0.997892
# 917552    32767                582    0.998275    0.998754    0.998179
#
#         ask_price2  bid_size1  ask_size1  bid_size2  ask_size2
# ...

# %%
# preprocess data
# calcWap 
# book_df
(book_example['bid_price1'] * book_example['ask_size1'] + book_example['ask_price1'] * book_example['bid_size1']) / (book_example['bid_size1'] + book_example['ask_size1'])
# Out:
# 0         1.001434
# 1         1.001448
# 2         1.001448
# 3         1.001443
# 4         1.001443
#             ...
# 917548    0.998515
# 917549    0.998516
# 917550    0.998516
# 917551    0.998517
# 917552    0.998517
# Length: 917553, dtype: float64

# %%
def preprocessor_book(df):
    pass
def preprocessor_trade(df):
    pass
def preprocessor():
    pass

# %%
# ------------------------------------------- baseline ---------------------------------------
